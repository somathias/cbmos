# %% [markdown]
# # Too large step sizes can lead to geometrical differences at the population level

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import scipy.integrate as scpi

import cbmos_serial as cbmos
import force_functions as ff
import euler_forward as ef
import adams_bashforth as ab
import midpoint as md
import heun as he
import cell as cl

plt.style.use('seaborn-whitegrid')
plt.style.use('tableau-colorblind10')
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (6.75, 5),
          'lines.linewidth': 3.0,
         'axes.labelsize': 'xx-large',
         'axes.titlesize':'xx-large',
         'xtick.labelsize':'xx-large',
         'ytick.labelsize':'xx-large',
          'legend.fontsize': 'xx-large',
         'font.size': 11,
          'font.family': 'serif',
          "mathtext.fontset": "dejavuserif",
         'axes.titlepad': 12,
        'axes.labelpad': 12}
plt.rcParams.update(params)

# %%
# plot function
def plot_population(ax, cell_list, color='blue'):
    #fig=plt.figure()
    #ax=fig.add_subplot(1,1,1, aspect='equal')
    #colors = 10*plt.rcParams['axes.prop_cycle'].by_key()['color']
    ax.set_aspect('equal')
    n_cells = len(cell_list)
    for i in range(n_cells):
        #ax.add_patch(plt.Circle(cell_list[i].position ,0.5,color=colors[i], alpha=0.6))
        ax.add_patch(plt.Circle(cell_list[i].position ,0.5,color=color, alpha=0.4))
        ax.plot(cell_list[i].position[0], cell_list[i].position[1], '.', color=color)
    #plt.show()
    #return fig

# %%
# calculate radius
def calculate_radius(cell_list):
    n_cells = len(cell_list)
    positions = np.array([cell.position for cell in cell_list])
    c = np.sum(positions, axis=0)/n_cells
    return 0.5 + max([np.linalg.norm(cell.position - c) for cell in cell_list])

# %%
# Simulation parameters
s = 1.0    # rest length
tf = 10.0  # final time
rA = 1.5   # maximum interaction distance
dim = 2
seed=67
t_data = np.linspace(0, tf, int(100*tf)+1)
n = 20

# %%
solver_names = ['EF', 'AB', 'midpoint', 'Heun']
force_names = ['cubic', 'pw. quad.', 'GLS']

defcolors = plt.rcParams['axes.prop_cycle'].by_key()['color']
colors = {'cubic': defcolors[0], 'pw. quad.': defcolors[5], 'GLS': defcolors[6]}
colors_list = [defcolors[0], defcolors[0], defcolors[0]]

# %%
# Solvers
solvers_ef = {'pw. quad.': cbmos.CBMSolver(ff.piecewise_polynomial, ef.solve_ivp, dim), 
             'cubic': cbmos.CBMSolver(ff.cubic, ef.solve_ivp, dim),
             'GLS': cbmos.CBMSolver(ff.gls, ef.solve_ivp, dim)}

# %% [markdown]
# ## Initial condition

# %%
# 2D honeycomb mesh
n_x = 5
n_y = 5
xcrds = [(2 * i + (j % 2)) * 0.5 for j in range(n_y) for i in range(n_x)]
ycrds = [np.sqrt(3) * j * 0.5 for j in range(n_y) for i in range(n_x)]

# make cell_list for the sheet
initial_sheet = [cl.Cell(i, [x,y], -24.0, True, lambda t: 24+t) for i, x, y in zip(range(n_x*n_y), xcrds, ycrds)]
# delete cells to make it circular
del initial_sheet[24]
del initial_sheet[20]
del initial_sheet[19]
del initial_sheet[9]
del initial_sheet[4]
del initial_sheet[0]

# %%
# plot to check what happend
fig, ax=plt.subplots(1,1)
plot_population(ax, initial_sheet)

# %%
#prepare consistent initial data
solver_scipy = cbmos.CBMSolver(ff.piecewise_polynomial, scpi.solve_ivp, dim)
t_data_init = [0, 0.0001]
sheet = solver_scipy.simulate(initial_sheet, t_data_init, {'muA': 0.21*9.1, 'muR': 9.1, 'rA': rA, 'rR': 1.0/(1.0-np.sqrt(0.21)/3.0), 'n': 1.0, 'p': 1.0}, {}, seed=seed)[-1]

# %%
# plot to check what happend
fig, ax=plt.subplots(1,1)
plot_population(ax, sheet)

# %% [markdown]
# # Using parameters fitted to relaxation time

# %%
params_cubic = {"mu": 5.70, "s": s, "rA": rA}
muR = 9.1
ratio = 0.21
params_poly = {'muA': ratio*muR, 'muR': muR, 'rA': rA, 'rR': 1.0/(1.0-np.sqrt(ratio)/3.0), 'n': 1.0, 'p': 1.0}
mu_gls=1.95
params_gls = {'mu': mu_gls, 'a':-2*np.log(0.002/mu_gls)}
params = {'cubic': params_cubic, 'pw. quad.': params_poly, 'GLS': params_gls}

# %% [markdown]
# ## Plot the sheet for different dt values

# %%
dt_values = [0.005, 0.075, 0.1]

# %%
pop_t_end = {'cubic': [], 'pw. quad.': [], 'GLS': []}
t_data_values = {}
for dt in dt_values:
    N = int(1/dt*tf) + 1
    #print([ N, dt])
    #t_data = np.linspace(0,1,N)
    t_data = np.arange(0,tf,dt)
    t_data_values[dt] = t_data
    for force in force_names:
        history = solvers_ef[force].simulate(sheet, t_data, params[force], {'dt': dt}, seed=seed)
        pop_t_end[force].append(history[-1])

# %%
for i, dt in enumerate(dt_values):
    fig, ax=plt.subplots(1,1)
    ax.set_xlim([-2, 6])
    ax.set_ylim([-2, 6])
    plot_population(ax, pop_t_end['cubic'][i], color=colors['cubic'])
    fig.savefig('pop_cubic_'+str(dt).replace('.', '_')+'.pdf')
    fig.savefig('pop_cubic_'+str(dt).replace('.', '_')+'.png')

# %%
for i, dt in enumerate(dt_values):
    fig, ax=plt.subplots(1,1)
    ax.set_xlim([-2, 6])
    ax.set_ylim([-2, 6])
    plot_population(ax, pop_t_end['pw. quad.'][i], color=colors['pw. quad.'])
    fig.savefig('pop_pw_quad_'+str(dt).replace('.', '_')+'.pdf')
    fig.savefig('pop_pw_quad_'+str(dt).replace('.', '_')+'.png')

# %%
for i, dt in enumerate(dt_values):
    fig, ax=plt.subplots(1,1)
    ax.set_xlim([-2, 6])
    ax.set_ylim([-2, 6])
    plot_population(ax, pop_t_end['GLS'][i], color=colors['GLS'])
    fig.savefig('pop_GLS_'+str(dt).replace('.', '_')+'.pdf')
    fig.savefig('pop_GLS_'+str(dt).replace('.', '_')+'.png')

# %%
# Make single figure with subplots
fig, ((ax1, ax2, ax3), (ax4, ax5, ax6), (ax7, ax8, ax9)) = plt.subplots(3,3, figsize=(15,15), sharey=True, sharex=True, gridspec_kw={'wspace':0.1})

#ax1
ax1.set_xlim([-2, 6])
ax1.set_ylim([-2, 6])
plot_population(ax1, pop_t_end['cubic'][0], color=colors['cubic'])
ax1.set(ylabel='Cubic force')
ax1.set_title(r'$\bf{(a)}$')
ax1.text(0, 7.5, r'$\Delta t = 0.005\,h$', fontsize=20)


#ax2
ax2.set_xlim([-2, 6])
#ax8.set_ylim([-2, 6])
plot_population(ax2, pop_t_end['cubic'][1], color=colors['cubic'])
ax2.set_title(r'$\bf{(b)}$')
ax2.text(0, 7.5, r'$\Delta t = 0.075\,h$', fontsize=20)


#ax3
ax3.set_xlim([-2, 6])
#ax7.set_ylim([-2, 6])
plot_population(ax3, pop_t_end['cubic'][2], color=colors['cubic'])
ax3.set_title(r'$\bf{(c)}$')
ax3.text(0.5, 7.5, r'$\Delta t = 0.1\,h$', fontsize=20)



#ax4
ax4.set_xlim([-2, 6])
ax4.set_ylim([-2, 6])
plot_population(ax4, pop_t_end['pw. quad.'][0], color=colors['pw. quad.'])
ax4.set_title(r'$\bf{(d)}$')
ax4.set(ylabel='Pw. quad. force')


#ax5
ax5.set_xlim([-2, 6])
#ax8.set_ylim([-2, 6])
plot_population(ax5, pop_t_end['pw. quad.'][1], color=colors['pw. quad.'])
ax5.set_title(r'$\bf{(e)}$')

#ax6
ax6.set_xlim([-2, 6])
#ax7.set_ylim([-2, 6])
plot_population(ax6, pop_t_end['pw. quad.'][2], color=colors['pw. quad.'])
ax6.set_title(r'$\bf{(f)}$')

#ax7
ax7.set_xlim([-2, 6])
ax7.set_ylim([-2, 6])
plot_population(ax7, pop_t_end['GLS'][0], color=colors['GLS'])
ax7.set_title(r'$\bf{(g)}$')
ax7.set(ylabel='GLS force')


#ax8
ax8.set_xlim([-2, 6])
#ax8.set_ylim([-2, 6])
plot_population(ax8, pop_t_end['GLS'][1], color=colors['GLS'])
ax8.set_title(r'$\bf{(h)}$')

#ax9
ax9.set_xlim([-2, 6])
#ax7.set_ylim([-2, 6])
plot_population(ax9, pop_t_end['GLS'][2], color=colors['GLS'])
ax9.set_title(r'$\bf{(i)}$')

plt.savefig('Fig12a_combined.pdf', bbox_inches='tight')

# %% [markdown]
# ## Get statistics on radii with more random seeds

# %%
radii = {'cubic': {}, 'pw. quad.': {}, 
         'GLS': {}}
for force in force_names:
    for dt in dt_values:
        t_data = np.arange(0,tf,dt)
        radii[force][dt] = np.zeros(len(t_data))
        
n = 15
for a in range(0,n):
    #prepare consistent initial data 
    sheet = solver_scipy.simulate(initial_sheet, t_data_init, {'muA': 0.21*9.1, 'muR': 9.1, 'rA': rA, 'rR': 1.0/(1.0-np.sqrt(0.21)/3.0), 'n': 1.0, 'p': 1.0}, {}, seed=a)[-1]
    
    for dt in dt_values:
        #N = int(1/dt*tf) + 1
        #print([ N, dt])
        #t_data = np.linspace(0,1,N)
        t_data = np.arange(0,tf,dt)
    
        for force in force_names:
            history = solvers_ef[force].simulate(sheet, t_data, params[force], {'dt': dt}, seed=a)
            length = min(len(t_data), len(history)) # catch off-by-one difference between t_data and EF
            radii[force][dt] = radii[force][dt] + np.array([calculate_radius(cl) for cl in history[:length]])

for force in force_names:
    for dt in dt_values:
        radii[force][dt] = radii[force][dt]/n

# %%
from matplotlib import lines
linestyles = list(lines.lineStyles.keys())

# %%
force='cubic'
for i,dt in enumerate(dt_values):
    plt.plot(t_data_values[dt], np.squeeze(radii[force][dt]), label='$\Delta t='+str(dt)+'\,h$',  linestyle=linestyles[i] , color=colors[force])
plt.ylabel('Population radius [cell diameters]')

plt.xlabel('Time [hours]')
plt.legend()
plt.savefig('radius_sensitivity_timestep_cubic.pdf', bbox_inches='tight')
plt.savefig('radius_sensitivity_timestep_cubic.png', bbox_inches='tight')

# %%
force='pw. quad.'
for i,dt in enumerate(dt_values):
    plt.plot(t_data_values[dt], np.squeeze(radii[force][dt]), label='$\Delta t='+str(dt)+'\,h$', linestyle=linestyles[i], color=colors[force] )
plt.ylabel('Population radius [cell diameters]')

plt.xlabel('Time [hours]')
plt.legend()
plt.savefig('radius_sensitivity_timestep_pwq.pdf', bbox_inches='tight')
plt.savefig('radius_sensitivity_timestep_pwq.png', bbox_inches='tight')

# %%
force='GLS'
for i,dt in enumerate(dt_values):
    plt.plot(t_data_values[dt], np.squeeze(radii[force][dt]), label='$\Delta t='+str(dt)+'\,h$',  linestyle=linestyles[i], color=colors[force] )
plt.ylabel('Population radius [cell diameters]')

plt.xlabel('Time [hours]')
plt.legend()
plt.savefig('radius_sensitivity_timestep_GLS.pdf', bbox_inches='tight')
plt.savefig('radius_sensitivity_timestep_GLS.png', bbox_inches='tight')

# %%
# Make single figure with subplots
params = {'font.size': 15}
plt.rcParams.update(params)
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(19.5,5), sharey=True, gridspec_kw={'wspace':0.1})


#ax1
force='cubic'
for i,dt in enumerate(dt_values):
    ax1.plot(t_data_values[dt], np.squeeze(radii[force][dt]), label='$\Delta t='+str(dt)+'\,h$',  linestyle=linestyles[i] , color=colors[force])
ax1.set(xlabel='Time [hours]', ylabel='Population radius \n[cell diameters]')
ax1.legend()
ax1.set_title(r'$\bf{(j)}$ Cubic force')

#ax2
force='pw. quad.'
for i,dt in enumerate(dt_values):
    ax2.plot(t_data_values[dt], np.squeeze(radii[force][dt]), label='$\Delta t='+str(dt)+'\,h$', linestyle=linestyles[i], color=colors[force] )
ax2.set(xlabel='Time [hours]')
ax2.legend()
ax2.set_title(r'$\bf{(k)}$ Pw. quad. force')


#ax3
force='GLS'
for i,dt in enumerate(dt_values):
    ax3.plot(t_data_values[dt], np.squeeze(radii[force][dt]), label='$\Delta t='+str(dt)+'\,h$',  linestyle=linestyles[i], color=colors[force] )
ax3.set(xlabel='Time [hours]')
ax3.legend()
ax3.set_title(r'$\bf{(l)}$ GLS force')

plt.savefig('Fig12b_combined.pdf', bbox_inches='tight')

# %% [markdown]
# ## Quantify relative differences between the force laws

# %%
dt_ref = 0.0005
N_ref = int(1/dt_ref*tf)+1
t_data_ref = np.arange(0, tf, dt_ref)

ref_traj = {}
for force in force_names: 
    print('>'+force)
    history = solvers_ef[force].simulate(sheet, t_data_ref, params[force], {'dt': dt_ref}, seed=seed)
    ref_traj[force] = {
        cell.ID: np.array([cell_list[i].position for cell_list in history])
        for i, cell in enumerate(history[0])
    }

print('Done.')
# Out:
# >cubic
# >pw. quad.
# >GLS
# Done.

# %%
# compare PWQ to GLS

error = 0
for ID, tr in ref_traj['pw. quad.'].items():
    ref = ref_traj['GLS'][ID]
    error = error + np.linalg.norm(tr-ref)/np.linalg.norm(ref)
error = error/38.0

# %%
error
# Out:
# 0.032119052737051824

# %%
# compare cubic to GLS

error_cubic = 0
for ID, tr in ref_traj['cubic'].items():
    ref = ref_traj['GLS'][ID]
    error_cubic = error_cubic + np.linalg.norm(tr-ref)/np.linalg.norm(ref)
error_cubic = error_cubic/38.0


error_cubic
# Out:
# 0.03910644428745829

# %%
# compare cubic to PWQ

error = 0
for ID, tr in ref_traj['cubic'].items():
    ref = ref_traj['pw. quad.'][ID]
    error = error + np.linalg.norm(tr-ref)/np.linalg.norm(ref)
error = error/38.0


error
# Out:
# 0.011431391549492494

# %%
# compare GLS to PWQ

error = 0
for ID, tr in ref_traj['GLS'].items():
    ref = ref_traj['pw. quad.'][ID]
    error = error + np.linalg.norm(tr-ref)/np.linalg.norm(ref)
error = error/38.0

error
# Out:
# 0.031084306570722493
