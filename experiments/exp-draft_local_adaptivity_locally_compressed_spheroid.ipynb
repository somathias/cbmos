# %% [markdown]
# # Local adaptive time-stepping for a locally compressed monolayer due to a single proliferation event

# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import scipy.integrate as scpi

import os 

import cbmos
import cbmos.force_functions as ff
import cbmos.solvers.euler_forward as ef
import cbmos.cell as cl

plt.style.use('seaborn-whitegrid')
plt.style.use('tableau-colorblind10')
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (6.75, 5),
          'lines.linewidth': 3.0, 
          'axes.labelsize': 'xx-large',
          'axes.titlesize':'xx-large',
          'xtick.labelsize':'xx-large', 
          'ytick.labelsize':'xx-large', 
          'legend.fontsize': 'xx-large', 
          'font.size': 11, 
          'font.family': 'serif', 
          'mathtext.fontset': 'dejavuserif', 
          'axes.titlepad': 12, 
          'axes.labelpad': 12}
plt.rcParams.update(params)

# %%
# Simulation parameters
s = 1.0    # rest length
tf = 7.5 # final time
rA = 1.5   # maximum interaction distance
separation = 0.15 # initial separation between daughter cells

dim = 3

seed=67
npr.seed(seed)

dt = 0.05
t_data = np.arange(0, tf, dt)

force_names = ['cubic', 'pw. quad.', 'GLS']

defcolors = plt.rcParams['axes.prop_cycle'].by_key()['color']
colors = {'cubic': defcolors[0], 'pw. quad.': defcolors[5], 'GLS': defcolors[6]}


# Solvers
models_ef = {'pw. quad.': cbmos.CBModel(ff.PiecewisePolynomial(), ef.solve_ivp, dim, separation), 
             'cubic': cbmos.CBModel(ff.Cubic(), ef.solve_ivp, dim, separation),
             'GLS': cbmos.CBModel(ff.Gls(), ef.solve_ivp, dim, separation)}
#models_ef = {'pw. quad.': cbmos.CBModel(ff.PiecewisePolynomial(), ef.solve_ivp, dim), 
#             'cubic': cbmos.CBModel(ff.Cubic(), ef.solve_ivp, dim),
 #            'GLS': cbmos.CBModel(ff.LinearExponential(), ef.solve_ivp, dim)}

# %%
# parameters fitted to relaxation time t=1.0h
params_cubic = {"mu": 5.70, "s": s, "rA": rA}
muR = 9.1
ratio = 0.21
params_poly = {'muA': ratio*muR, 'muR': muR, 'rA': rA, 'rR': 1.0/(1.0-np.sqrt(ratio)/3.0), 'n': 1.0, 'p': 1.0}
mu_gls=1.95
params_gls = {'mu': mu_gls, 'a':-2*np.log(0.002/mu_gls)}
params = {'cubic': params_cubic, 'pw. quad.': params_poly, 'GLS': params_gls}
filename_ending = {'cubic': '_cubic', 'pw. quad.': '_pwq', 'GLS': '_gls'}

# %%
def cubic_prime(r, mu, s, rA):
    return mu*(r-rA)*(3*r-2*s-rA)
    
def pwq_prime(r, muA, rA, muR, rR, s):
    return 2*(muR/rR*(1-r/rR)-muA/rA*(1-r/rA))
    
def gls_prime(r, mu, s):
    return mu/(1+r-s)

# %%
def make_hexagonal_mesh(l):
# 2D honeycomb mesh
#l=3
    n_x = l+(l//2)+((l-1)//2)
    n_y = l+(l-1)
    xcrds = [(2 * i + (j % 2)) * 0.5 for j in range(n_y) for i in range(n_x)]
    ycrds = [np.sqrt(3) * j * 0.5 for j in range(n_y) for i in range(n_x)]

    # make cell_list for the sheet
    sheet = [cl.Cell(i, [x,y], 0.0, proliferating=False) for i, x, y in zip(range(n_x*n_y), xcrds, ycrds)]

    # delete cells to make it circular - skip for now
    #del sheet[24]
    #del sheet[20]
    #del sheet[19]
    #del sheet[3*l+1+3+1]
    #del sheet[2*l+1+3]
    #del sheet[2*l+1+2]
    #del sheet[l+1]
    #del sheet[0]

    # find middle index, move cell there and add second daughter cells
    m = n_x *(n_y//2)+ n_x//2
    coords = list(sheet[m].position)
    
    # get division direction
    random_angle = 2.0 * np.pi * npr.rand()
    division_direction = np.array([np.cos(random_angle), np.sin(random_angle)])
    
    # update positions
    updated_position_parent = coords - 0.5 * separation * division_direction
    sheet[m].position = updated_position_parent   

    position_daughter = coords + 0.5 * separation * division_direction    
    
    # add daughter cell
    next_cell_index = len(sheet)
    daughter_cell = cl.Cell(next_cell_index, position_daughter, birthtime=0.0, proliferating=False)
    sheet.append(daughter_cell)
        
    return sheet

# %%
# plot function
def plot_population(cell_list, color='blue'):
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    #colors = 10*plt.rcParams['axes.prop_cycle'].by_key()['color']
    n_cells = len(cell_list)
    for i in range(n_cells):
        #ax.add_patch(plt.Circle(cell_list[i].position ,0.5,color=colors[i], alpha=0.6))
        ax.add_patch(plt.Circle(cell_list[i].position ,0.5,color=color, alpha=0.4))
        plt.plot(cell_list[i].position[0], cell_list[i].position[1], '.', color=color)
    plt.show()

# %%
# plot function
# eigenvector must contain eigenvector corresponding to a single eigenvalue
def plot_eigenvector_on_population(cell_list, eigenvector, color='blue'):
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    #colors = 10*plt.rcParams['axes.prop_cycle'].by_key()['color']
    n_cells = len(cell_list)
    eigenvector = eigenvector.reshape((n_cells, -1))
    for i in range(n_cells):
        #ax.add_patch(plt.Circle(cell_list[i].position ,0.5,color=colors[i], alpha=0.6))
        ax.add_patch(plt.Circle(cell_list[i].position ,0.5,color=color, alpha=0.4))
        plt.plot(cell_list[i].position[0], cell_list[i].position[1], '.', color=color)
        plt.plot([cell_list[i].position[0], cell_list[i].position[0] + eigenvector[i, 0]], [cell_list[i].position[1],cell_list[i].position[1]+eigenvector[i,1]])
    plt.show()

# %%
def make_hcp_mesh(n_x, n_y, n_z, scaling=1.0):
# 3D honeycomb mesh

    coords = [((2 * i_x + ((i_y + i_z) % 2)) * 0.5 * scaling,
             np.sqrt(3) * (i_y + (i_z % 2) / 3.0) * 0.5 * scaling,
             np.sqrt(6) * i_z / 3.0 * scaling)
            for i_x in range(n_x) for i_y in range(n_y) for i_z in range(n_z)
            ]


    # make cell_list for the sheet
    sheet = [cl.Cell(i, [x,y,z], 0.0, proliferating=False) for i, (x, y, z) in enumerate(coords)]


    # find middle index, move cell there and add second daughter cells
    m = (n_x*n_y)*(n_z//2)+n_x*(n_y//2)+n_x//2
    coords = list(sheet[m].position)
    
    # get division direction
    u = npr.rand()
    v = npr.rand()
    random_azimuth_angle = 2 * np.pi * u
    random_zenith_angle = np.arccos(2 * v - 1)
    division_direction = np.array([
                np.cos(random_azimuth_angle) * np.sin(random_zenith_angle),
                np.sin(random_azimuth_angle) * np.sin(random_zenith_angle),
                np.cos(random_zenith_angle)])
    
    # update positions
    updated_position_parent = coords - 0.5 * separation * division_direction
    sheet[m].position = updated_position_parent   

    position_daughter = coords + 0.5 * separation * division_direction    
    
    # add daughter cell
    next_cell_index = len(sheet)
    daughter_cell = cl.Cell(next_cell_index, position_daughter, birthtime=0.0, proliferating=False)
    sheet.append(daughter_cell)
        
    return sheet

# %%
sheet = make_hcp_mesh(6,6,6)

# %%
colors = [defcolors[0], defcolors[5], defcolors[6]]

# Combine into single figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), gridspec_kw={'hspace':0.2, 'wspace': 0.3})
#fig2, (ax3, ax4) = plt.subplots(1, 2, figsize=(12, 5), sharex=True, sharey='row', gridspec_kw={'hspace':0.2, 'wspace': 0.15})


force = 'cubic'
epsilons = [0.05, 0.01, 0.002]

for i, eps in enumerate(epsilons):
    
    try:
        os.remove('step_sizes'+filename_ending[force]+'.txt')
    except FileNotFoundError:
        print('Nothing to delete.')
        
    try:
        os.remove('n_eq_per_level'+filename_ending[force]+'.txt')
    except FileNotFoundError:
        print('Nothing to delete.')

    ts, history = models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True,'jacobian': models_ef[force].jacobian, 'force_args': params[force], 'local_adaptivity': True}, seed=seed)
    #ts, history = models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True, 'local_adaptivity': True}, seed=seed)

    dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')
    print('Initial step '+force + ' ' +str(dts[0]))
    print('Stability bound estimate '+force + ' ' +str((dts[-2]+dts[-1])/2.0))
    ax1.plot(ts[:-2], dts[:-1],'-*', label='$\epsilon=$'+str(eps), color=colors[i])
    
    n_eq_per_level = np.loadtxt('n_eq_per_level'+filename_ending[force]+'.txt')
    ax2.plot(ts[:-1], n_eq_per_level[2,:], label='$\epsilon=$'+str(eps), color=colors[i])

ax1.set_title(r'$\bf{(e)}$')
ax1.legend(loc='lower right')
ax1.set(xlabel='Time in hours')
ax1.set(ylabel='$\Delta t_{max}$ in hours')
ax1.text(-4.5, 0.01, 'Locally compressed\n        monolayer', fontsize=22, rotation='vertical')
#ax1.set(ylim=[-0.01, 0.18])


#ax2.set(ylim=[-0.1, 1.2])
#ax2.text(3.4, 1.45, '$\epsilon=0.001$', fontsize=22)

ax2.legend()
ax2.set(xlabel='Time in hours')
ax2.set(ylabel='#Equations with $\Delta t_{max}$')
ax2.set_title(r'$\bf{(f)}$')




plt.savefig('local_adap_local_mono.pdf', bbox_inches='tight')
# Out:
# Initial step cubic 0.016530373257954725
# Stability bound estimate cubic 0.03848020672077872
# Initial step cubic 0.015922935245087914
# Stability bound estimate cubic 0.04064297292856714
# Initial step cubic 0.00712095312186877
# Stability bound estimate cubic 0.05212635860834748

# %%
# do preliminary measuring of the execution times
eps = 0.01
sheet = make_hexagonal_mesh(20)
len(sheet)
# Out:
# 1522

# %%
#plot_population(sheet)

# %%
# %%time
ts, history = models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps, "eta":0.0001, "out": filename_ending[force], 'write_to_file': False,'jacobian': models_ef[force].jacobian, 'force_args': params[force], 'local_adaptivity': True}, seed=seed)
# Out:
# CPU times: user 5.63 s, sys: 1.92 s, total: 7.55 s
# Wall time: 9.2 s

# %%
# %%time
ts, history = models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps, "eta":0.0001, "out": filename_ending[force], 'write_to_file': False,'jacobian': models_ef[force].jacobian, 'force_args': params[force]}, seed=seed)
# Out:
# CPU times: user 5.73 s, sys: 3.42 s, total: 9.15 s
# Wall time: 11.9 s

# %%
import cProfile

# %%
cProfile.run('models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps, "eta":0.0001, "out": filename_ending[force], "write_to_file": False, "jacobian": models_ef[force].jacobian, "force_args": params[force], "local_adaptivity": True}, seed=seed)', sort=1)
# Out:
#          82799 function calls (82657 primitive calls) in 9.502 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        14    4.504    0.322    6.266    0.448 __init__.py:349(jacobian)
#       134    1.825    0.014    1.825    0.014 {method 'reduce' of 'numpy.ufunc' objects}
#        14    1.343    0.096    2.578    0.184 __init__.py:326(f)
#       236    0.618    0.003    0.618    0.003 {method 'reshape' of 'numpy.ndarray' objects}
#        14    0.403    0.029    6.765    0.483 euler_forward.py:424(_choose_dts)
#        42    0.367    0.009    0.434    0.010 force_functions.py:157(__call__)
#        14    0.106    0.008    0.134    0.010 force_functions.py:177(fp)
#        84    0.098    0.001    0.098    0.001 {built-in method numpy.zeros}
#     24352    0.066    0.000    0.076    0.000 cell.py:46(__init__)
#        28    0.058    0.002    0.061    0.002 twodim_base.py:214(diag)
#         1    0.023    0.023    9.375    9.375 euler_forward.py:276(_do_local_adaptive_timestepping)
#        14    0.023    0.002    0.090    0.006 __init__.py:228(<listcomp>)
#     26216    0.022    0.000    0.022    0.000 {built-in method numpy.array}
#      1522    0.011    0.000    0.013    0.000 {built-in method _heapq.heappop}
#         1    0.005    0.005    0.018    0.018 _eventqueue.py:35(pop)
#        84    0.002    0.000    0.003    0.000 numeric.py:1308(normalize_axis_tuple)
#     15449    0.002    0.000    0.002    0.000 cell.py:64(__lt__)
#         1    0.001    0.001    0.003    0.003 __init__.py:234(<listcomp>)
#        14    0.001    0.000    0.001    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#   284/254    0.001    0.000    0.163    0.001 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         1    0.001    0.001    0.009    0.009 __init__.py:108(<listcomp>)
#         1    0.001    0.001    9.502    9.502 __init__.py:39(simulate)
#        14    0.001    0.000    0.003    0.000 arrayprint.py:863(fillFormat)
#        56    0.001    0.000    0.002    0.000 shape_base.py:512(expand_dims)
#         1    0.001    0.001    0.001    0.001 {built-in method _heapq.heapify}
#        56    0.001    0.000    1.734    0.031 {method 'sum' of 'numpy.ndarray' objects}
#         1    0.001    0.001    0.002    0.002 __init__.py:303(_update_positions)
#        55    0.001    0.000    0.006    0.000 {method 'format' of 'str' objects}
#        70    0.001    0.000    0.092    0.001 fromnumeric.py:70(_wrapreduction)
#       168    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_scientific}
#      4361    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.001    0.001 _eventqueue.py:18(<listcomp>)
#        84    0.000    0.000    0.001    0.000 arrayprint.py:947(__call__)
#     98/14    0.000    0.000    0.001    0.000 arrayprint.py:718(recurser)
#        84    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#        56    0.000    0.000    0.001    0.000 _ufunc_config.py:32(seterr)
#        28    0.000    0.000    0.092    0.003 fromnumeric.py:2105(sum)
#        11    0.000    0.000    0.000    0.000 euler_forward.py:544(_do_single_level)
#        56    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        57    0.000    0.000    0.001    0.000 {built-in method builtins.max}
#        14    0.000    0.000    0.003    0.000 numeric.py:1371(moveaxis)
#       178    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#        56    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(expand_dims)
#        14    0.000    0.000    0.000    0.000 twodim_base.py:152(eye)
#        56    0.000    0.000    0.000    0.000 __init__.py:1904(debug)
#     42/14    0.000    0.000    0.000    0.000 arrayprint.py:324(_leading_trailing)
#        14    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        14    0.000    0.000    0.005    0.000 arrayprint.py:478(_array2string)
#        56    0.000    0.000    1.733    0.031 _methods.py:45(_sum)
#        56    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#        28    0.000    0.000    0.000    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.001    0.000 numeric.py:2084(identity)
#         2    0.000    0.000    0.000    0.000 euler_forward.py:567(_do_three_levels)
#      1809    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#        14    0.000    0.000    0.006    0.000 arrayprint.py:516(array2string)
#        28    0.000    0.000    0.092    0.003 <__array_function__ internals>:2(sum)
#        98    0.000    0.000    0.000    0.000 arrayprint.py:888(<genexpr>)
#      1522    0.000    0.000    0.000    0.000 __init__.py:114(<lambda>)
#        14    0.000    0.000    0.003    0.000 arrayprint.py:409(_get_format_function)
#         1    0.000    0.000    0.000    0.000 __init__.py:121(<listcomp>)
#      1522    0.000    0.000    0.000    0.000 _eventqueue.py:51(_round_time)
#       229    0.000    0.000    0.001    0.000 _asarray.py:86(asanyarray)
#        98    0.000    0.000    0.000    0.000 arrayprint.py:695(_extendLine)
#       112    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#         1    0.000    0.000    0.000    0.000 __init__.py:155(<listcomp>)
#        28    0.000    0.000    0.001    0.000 _ufunc_config.py:438(__exit__)
#        92    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        84    0.000    0.000    0.000    0.000 numeric.py:1358(<listcomp>)
#        14    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.005    0.000 arrayprint.py:461(wrapper)
#        28    0.000    0.000    0.062    0.002 <__array_function__ internals>:2(diag)
#        98    0.000    0.000    0.000    0.000 arrayprint.py:896(<genexpr>)
#        14    0.000    0.000    0.001    0.000 numeric.py:144(ones)
#        56    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#        14    0.000    0.000    0.000    0.000 arrayprint.py:60(_make_options_dict)
#         8    0.000    0.000    0.000    0.000 _methods.py:143(_mean)
#        14    0.000    0.000    0.000    0.000 copy.py:132(deepcopy)
#        28    0.000    0.000    0.001    0.000 fromnumeric.py:2714(amin)
#        14    0.000    0.000    0.003    0.000 arrayprint.py:836(__init__)
#        14    0.000    0.000    0.006    0.000 arrayprint.py:1473(_array_str_implementation)
#        14    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        14    0.000    0.000    0.000    0.000 arrayprint.py:358(_get_formatdict)
#        14    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#        28    0.000    0.000    0.001    0.000 _ufunc_config.py:433(__enter__)
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         8    0.000    0.000    0.001    0.000 fromnumeric.py:3269(mean)
#        28    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(amin)
#         1    0.000    0.000    9.502    9.502 {built-in method builtins.exec}
#        70    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#         6    0.000    0.000    0.000    0.000 shape_base.py:24(atleast_1d)
#        28    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#        14    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(moveaxis)
#        70    0.000    0.000    0.000    0.000 _asarray.py:14(asarray)
#        56    0.000    0.000    0.000    0.000 __init__.py:1544(isEnabledFor)
#        98    0.000    0.000    0.000    0.000 arrayprint.py:891(<genexpr>)
#        42    0.000    0.000    0.002    0.000 fromnumeric.py:52(_wrapfunc)
#        56    0.000    0.000    0.000    0.000 shape_base.py:600(<listcomp>)
#        15    0.000    0.000    0.093    0.006 __init__.py:216(_save_data)
#        14    0.000    0.000    0.002    0.000 fromnumeric.py:999(argsort)
#        14    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#        14    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(argsort)
#         1    0.000    0.000    0.000    0.000 euler_forward.py:552(_do_two_levels)
#        14    0.000    0.000    0.000    0.000 copy.py:252(_keep_alive)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:1502(diagonal)
#        56    0.000    0.000    0.000    0.000 __init__.py:1286(debug)
#        28    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(searchsorted)
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        22    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#        14    0.000    0.000    0.003    0.000 arrayprint.py:366(<lambda>)
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#         8    0.000    0.000    0.000    0.000 _methods.py:59(_count_reduce_items)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:1276(searchsorted)
#        84    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        44    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:2589(amax)
#         2    0.000    0.000    0.000    0.000 shape_base.py:82(atleast_2d)
#        14    0.000    0.000    0.000    0.000 force_functions.py:176(derive)
#        84    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        56    0.000    0.000    0.000    0.000 __init__.py:1530(getEffectiveLevel)
#        14    0.000    0.000    0.001    0.000 arrayprint.py:709(_formatArray)
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diagonal)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:2100(_sum_dispatcher)
#        56    0.000    0.000    0.000    0.000 shape_base.py:508(_expand_dims_dispatcher)
#        28    0.000    0.000    0.000    0.000 index_tricks.py:727(__getitem__)
#        14    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        14    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(amax)
#        14    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#        98    0.000    0.000    0.000    0.000 arrayprint.py:892(<genexpr>)
#        84    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#        14    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    9.502    9.502 <string>:1(<module>)
#         6    0.000    0.000    0.000    0.000 shape_base.py:286(hstack)
#        86    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#       126    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        98    0.000    0.000    0.000    0.000 arrayprint.py:893(<genexpr>)
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         8    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(mean)
#        28    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#        28    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        28    0.000    0.000    0.000    0.000 twodim_base.py:210(_diag_dispatcher)
#        14    0.000    0.000    0.000    0.000 arrayprint.py:65(<dictcomp>)
#        98    0.000    0.000    0.000    0.000 arrayprint.py:903(<genexpr>)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:2709(_amin_dispatcher)
#        28    0.000    0.000    0.000    0.000 fromnumeric.py:1272(_searchsorted_dispatcher)
#         1    0.000    0.000    9.375    9.375 __init__.py:294(_calculate_positions)
#        14    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#        14    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#         1    0.000    0.000    9.375    9.375 euler_forward.py:16(solve_ivp)
#        28    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         1    0.000    0.000    0.000    0.000 {method 'seed' of 'numpy.random.mtrand.RandomState' objects}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:995(_argsort_dispatcher)
#        14    0.000    0.000    0.000    0.000 numeric.py:1367(_moveaxis_dispatcher)
#        14    0.000    0.000    0.000    0.000 numeric.py:1434(<listcomp>)
#        14    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         1    0.000    0.000    0.002    0.002 _eventqueue.py:13(__init__)
#        22    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#        14    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#        14    0.000    0.000    0.000    0.000 multiarray.py:1043(copyto)
#         6    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#         8    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:223(vstack)
#         3    0.000    0.000    0.000    0.000 optimize.py:120(__getattr__)
#         6    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(hstack)
#         8    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:1498(_diagonal_dispatcher)
#         5    0.000    0.000    0.000    0.000 {built-in method time.time}
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#        14    0.000    0.000    0.000    0.000 arrayprint.py:827(_none_or_positive_arg)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:3265(_mean_dispatcher)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 __init__.py:313(_ode_system)
#        14    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_amax_dispatcher)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#         6    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#         1    0.000    0.000    0.000    0.000 __init__.py:154(<listcomp>)
#         2    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run('models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps, "eta":0.0001, "out": filename_ending[force], "write_to_file": False, "jacobian": models_ef[force].jacobian, "force_args": params[force]}, seed=seed)', sort=1)
# Out:
#          85232 function calls (85210 primitive calls) in 14.687 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#        16    6.549    0.409    9.394    0.587 __init__.py:349(jacobian)
#       124    2.931    0.024    2.931    0.024 {method 'reduce' of 'numpy.ufunc' objects}
#        16    2.254    0.141    4.172    0.261 __init__.py:326(f)
#       195    1.016    0.005    1.016    0.005 {method 'reshape' of 'numpy.ndarray' objects}
#         1    0.691    0.691   14.438   14.438 euler_forward.py:164(_do_global_adaptive_timestepping_with_stability)
#        48    0.560    0.012    0.670    0.014 force_functions.py:157(__call__)
#        16    0.188    0.012    0.233    0.015 force_functions.py:177(fp)
#        96    0.161    0.002    0.161    0.002 {built-in method numpy.zeros}
#     29205    0.082    0.000    0.082    0.000 {built-in method numpy.array}
#        16    0.066    0.004    0.141    0.009 __init__.py:228(<listcomp>)
#        32    0.060    0.002    0.065    0.002 twodim_base.py:214(diag)
#     27396    0.042    0.000    0.105    0.000 cell.py:46(__init__)
#      1522    0.036    0.000    0.053    0.000 {built-in method _heapq.heappop}
#     15449    0.028    0.000    0.028    0.000 cell.py:64(__lt__)
#         1    0.005    0.005   14.687   14.687 __init__.py:39(simulate)
#        32    0.002    0.000    0.176    0.006 fromnumeric.py:70(_wrapreduction)
#         1    0.001    0.001    0.030    0.030 __init__.py:108(<listcomp>)
#         1    0.001    0.001    0.003    0.003 __init__.py:234(<listcomp>)
#         1    0.001    0.001    0.054    0.054 _eventqueue.py:35(pop)
#   213/191    0.001    0.000    0.247    0.001 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        64    0.001    0.000    0.002    0.000 shape_base.py:512(expand_dims)
#         1    0.001    0.001    0.012    0.012 {built-in method _heapq.heapify}
#        96    0.001    0.000    0.001    0.000 numeric.py:1308(normalize_axis_tuple)
#        64    0.001    0.000    2.757    0.043 {method 'sum' of 'numpy.ndarray' objects}
#        16    0.001    0.000    0.001    0.000 linalg.py:2363(norm)
#         1    0.000    0.000    0.002    0.002 __init__.py:303(_update_positions)
#      3438    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 _eventqueue.py:18(<listcomp>)
#        32    0.000    0.000    0.001    0.000 _ufunc_config.py:32(seterr)
#        16    0.000    0.000    0.001    0.000 twodim_base.py:152(eye)
#        16    0.000    0.000    0.000    0.000 {built-in method numpy.empty}
#        32    0.000    0.000    0.000    0.000 _ufunc_config.py:132(geterr)
#        64    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(expand_dims)
#        16    0.000    0.000    0.001    0.000 numeric.py:1371(moveaxis)
#       139    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        18    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#        16    0.000    0.000    0.001    0.000 numeric.py:2084(identity)
#        64    0.000    0.000    2.756    0.043 _methods.py:45(_sum)
#         1    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:121(<listcomp>)
#        16    0.000    0.000    0.175    0.011 fromnumeric.py:2105(sum)
#      1669    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000   14.438   14.438 euler_forward.py:16(solve_ivp)
#        32    0.000    0.000    0.000    0.000 {built-in method numpy.seterrobj}
#      1522    0.000    0.000    0.000    0.000 __init__.py:114(<lambda>)
#        17    0.000    0.000    0.144    0.008 __init__.py:216(_save_data)
#      1522    0.000    0.000    0.000    0.000 _eventqueue.py:51(_round_time)
#        16    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#        16    0.000    0.000    0.001    0.000 numeric.py:144(ones)
#        19    0.000    0.000    0.000    0.000 __init__.py:1904(debug)
#        16    0.000    0.000    0.001    0.000 _ufunc_config.py:438(__exit__)
#        32    0.000    0.000    0.065    0.002 <__array_function__ internals>:2(diag)
#        96    0.000    0.000    0.000    0.000 numeric.py:1358(<listcomp>)
#       108    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#        16    0.000    0.000    0.000    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 copy.py:132(deepcopy)
#        12    0.000    0.000    0.000    0.000 _methods.py:143(_mean)
#        64    0.000    0.000    0.000    0.000 {built-in method numpy.geterrobj}
#        64    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#       174    0.000    0.000    0.000    0.000 _asarray.py:86(asanyarray)
#        80    0.000    0.000    0.000    0.000 _asarray.py:14(asarray)
#        16    0.000    0.000    0.175    0.011 <__array_function__ internals>:2(sum)
#         1    0.000    0.000    0.000    0.000 __init__.py:155(<listcomp>)
#        16    0.000    0.000    0.002    0.000 fromnumeric.py:2714(amin)
#        64    0.000    0.000    0.000    0.000 shape_base.py:600(<listcomp>)
#        16    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(moveaxis)
#        16    0.000    0.000    0.000    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.sorted}
#         1    0.000    0.000   14.687   14.687 {built-in method builtins.exec}
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:3269(mean)
#        16    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(norm)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(copyto)
#        16    0.000    0.000    0.002    0.000 <__array_function__ internals>:2(amin)
#        16    0.000    0.000    0.000    0.000 copy.py:252(_keep_alive)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:1502(diagonal)
#        32    0.000    0.000    0.000    0.000 fromnumeric.py:71(<dictcomp>)
#        16    0.000    0.000    0.000    0.000 _ufunc_config.py:429(__init__)
#        16    0.000    0.000    0.000    0.000 linalg.py:2359(_norm_dispatcher)
#        16    0.000    0.000    0.001    0.000 {method 'max' of 'numpy.ndarray' objects}
#        16    0.000    0.000    0.000    0.000 _ufunc_config.py:433(__enter__)
#        12    0.000    0.000    0.000    0.000 _methods.py:59(_count_reduce_items)
#        47    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        16    0.000    0.000    0.000    0.000 force_functions.py:176(derive)
#        16    0.000    0.000    0.000    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#        19    0.000    0.000    0.000    0.000 __init__.py:1544(isEnabledFor)
#        56    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#        32    0.000    0.000    0.000    0.000 {built-in method builtins.abs}
#        19    0.000    0.000    0.000    0.000 __init__.py:1286(debug)
#        16    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(diagonal)
#        16    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#        64    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        64    0.000    0.000    0.000    0.000 shape_base.py:508(_expand_dims_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:24(atleast_1d)
#        32    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000   14.687   14.687 <string>:1(<module>)
#        32    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#        16    0.000    0.000    0.001    0.000 _methods.py:37(_amax)
#       144    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        12    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(mean)
#        32    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#        16    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        32    0.000    0.000    0.000    0.000 twodim_base.py:210(_diag_dispatcher)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:2709(_amin_dispatcher)
#        19    0.000    0.000    0.000    0.000 __init__.py:1530(getEffectiveLevel)
#         1    0.000    0.000   14.438   14.438 __init__.py:294(_calculate_positions)
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:2100(_sum_dispatcher)
#        16    0.000    0.000    0.000    0.000 numeric.py:1434(<listcomp>)
#         1    0.000    0.000    0.000    0.000 shape_base.py:82(atleast_2d)
#         1    0.000    0.000    0.012    0.012 _eventqueue.py:13(__init__)
#        16    0.000    0.000    0.000    0.000 numeric.py:1367(_moveaxis_dispatcher)
#        48    0.000    0.000    0.000    0.000 {built-in method builtins.id}
#         1    0.000    0.000    0.000    0.000 {method 'seed' of 'numpy.random.mtrand.RandomState' objects}
#        16    0.000    0.000    0.000    0.000 fromnumeric.py:1498(_diagonal_dispatcher)
#         2    0.000    0.000    0.000    0.000 shape_base.py:286(hstack)
#         3    0.000    0.000    0.000    0.000 optimize.py:120(__getattr__)
#        16    0.000    0.000    0.000    0.000 multiarray.py:1043(copyto)
#         1    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method time.time}
#        12    0.000    0.000    0.000    0.000 fromnumeric.py:3265(_mean_dispatcher)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(hstack)
#         3    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(concatenate)
#         1    0.000    0.000    0.000    0.000 shape_base.py:223(vstack)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_1d)
#         3    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(vstack)
#         1    0.000    0.000    0.000    0.000 __init__.py:154(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:313(_ode_system)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:2(atleast_2d)
#         3    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#         3    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#         2    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#         1    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
colors = [defcolors[0], defcolors[5], defcolors[6]]
# Combine into single figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharex=True, sharey='row', gridspec_kw={'hspace':0.2, 'wspace': 0.15})
fig2, (ax3, ax4) = plt.subplots(1, 2, figsize=(12, 5), sharex=True, sharey='row', gridspec_kw={'hspace':0.2, 'wspace': 0.15})

#ax1 No Jacobian - accuracy bound only
#ax1.plot(t_data, 1.0/gp_cubic*np.ones(len(t_data)), linestyle='--', color=defcolors[2])
#ax1.plot(t_data, 1.0/gp_PWQ*np.ones(len(t_data)), linestyle='--', color=colors['pw. quad.'] )
#ax1.plot(t_data, 1.0/gp_GLS*np.ones(len(t_data)), linestyle='--', color=colors['GLS'] )

force = 'cubic'
epsilons = [0.05, 0.01, 0.001]

for i, eps in enumerate(epsilons):
    
    try:
        os.remove('step_sizes'+filename_ending[force]+'.txt')
    except FileNotFoundError:
        print('Nothing to delete.')
        
    try:
        os.remove('n_eq_per_level'+filename_ending[force]+'.txt')
    except FileNotFoundError:
        print('Nothing to delete.')
    
    ts, history = models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps,"eta":0.0001, "out": filename_ending[force], 'write_to_file': True, "local_adaptivity": True}, seed=seed)
    dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')
    print('Initial step '+force + ' ' +str(dts[0]))
    print('Stability bound estimate '+force + ' ' +str((dts[-2]+dts[-1])/2.0))
    #ts = np.loadtxt('time_points'+filename_ending[force]+'.txt')
    ax1.plot(ts[:-1], dts,'-*', label='$\epsilon=$'+str(eps), color=colors[i])




ax1.legend()
ax1.set_title(r'$\bf{(e)}$')
ax1.set(xlabel='Time in hours')
ax1.set(ylabel='$\Delta t_0$ in hours')
#ax1.set(ylim=[-0.1, 1.2])
ax1.text(-5.5, 0.1, 'Locally compressed\n        monolayer', fontsize=22, rotation='vertical')
#ax1.text(3.7, 1.45, '$\epsilon=0.01$', fontsize=22)

n_eq_per_level = np.loadtxt('n_eq_per_level'+filename_ending[force]+'.txt')
ax3.plot(ts[:-1], n_eq_per_level[0,:], label='level 0', color=colors[0])
ax3.plot(ts[:-1], n_eq_per_level[1,:], label='level 1', color=colors[1])
ax3.plot(ts[:-1], n_eq_per_level[2,:], label='level 2', color=colors[2])
ax3.legend()
ax3.set(xlabel='Time in hours')
ax3.set(ylabel='#Equations')
ax3.text(-5.5, 0.1, 'Locally compressed\n        monolayer', fontsize=22, rotation='vertical')


#ax2
#ax2.plot(t_data, 1.0/gp_cubic*np.ones(len(t_data)), linestyle='--', color=defcolors[2])
#ax2.plot(t_data, 1.0/gp_PWQ*np.ones(len(t_data)), linestyle='--', color=colors['pw. quad.'] )
#ax2.plot(t_data, 1.0/gp_GLS*np.ones(len(t_data)), linestyle='--', color=colors['GLS'] )


for i, eps in enumerate(epsilons):
    
    try:
        os.remove('step_sizes'+filename_ending[force]+'.txt')
    except FileNotFoundError:
        print('Nothing to delete.')
        
    try:
        os.remove('n_eq_per_level'+filename_ending[force]+'.txt')
    except FileNotFoundError:
        print('Nothing to delete.')
    
    ts, history = models_ef[force].simulate(sheet, t_data, params[force], {"eps": eps, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True, 'jacobian': models_ef[force].jacobian, 'force_args': params[force], "local_adaptivity": True, "switch":True, "K":3}, seed=seed)
    dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')
    print('Initial step '+force + ' ' +str(dts[0]))
    print('Stability bound estimate '+force + ' ' +str((dts[-2]+dts[-1])/2.0))
    ax2.plot(ts[:-2], dts[:-1], '-*', label='$\epsilon=$'+str(eps), color=colors[i])

ax2.set_title(r'$\bf{(f)}$')
ax2.legend()
ax2.set(xlabel='Time in hours')
#ax2.set(ylabel='$\Delta t$ in hours')
#ax2.set(ylim=[-0.1, 1.2])
#ax2.text(3.4, 1.45, '$\epsilon=0.001$', fontsize=22)

n_eq_per_level = np.loadtxt('n_eq_per_level'+filename_ending[force]+'.txt')
ax4.plot(ts[:-1], n_eq_per_level[0,:], label='level 0', color=colors[0])
ax4.plot(ts[:-1], n_eq_per_level[1,:], label='level 1', color=colors[1])
ax4.plot(ts[:-1], n_eq_per_level[2,:], label='level 2', color=colors[2])
ax4.legend()
ax4.set(xlabel='Time in hours')
ax4.set(ylabel='#Equations')

plt.savefig('local_adap_local_mono.pdf', bbox_inches='tight')
# Out:
# Initial step cubic 0.030948752289243944
# Stability bound estimate cubic 0.07381457849427374
# Initial step cubic 0.01384070278751034
# Stability bound estimate cubic 0.10338777986641061
# Initial step cubic 0.0043768145225974164
# Stability bound estimate cubic 0.1906067442394846
# Initial step cubic 0.022304376240639866
# Stability bound estimate cubic 0.31071989343024464
# Initial step cubic 0.013831483646606593
# Stability bound estimate cubic 0.23233295705291157
# Initial step cubic 0.00437389917426483
# Stability bound estimate cubic 0.10186778481249775
