# %%
import numpy as np
import numpy.random as npr
import matplotlib.pyplot as plt
from scipy.optimize import minimize
import scipy.integrate as scpi

import os 

import cbmos
import cbmos.force_functions as ff
import cbmos.solvers.euler_forward as ef
import cbmos.cell as cl

plt.style.use('seaborn-whitegrid')
plt.style.use('tableau-colorblind10')
params = {'legend.fontsize': 'xx-large',
          'figure.figsize': (6.75, 5),
          'lines.linewidth': 3.0, 
          'axes.labelsize': 'xx-large',
          'axes.titlesize':'xx-large',
          'xtick.labelsize':'xx-large', 
          'ytick.labelsize':'xx-large', 
          'legend.fontsize': 'xx-large', 
          'font.size': 11, 
          'font.family': 'serif', 
          'mathtext.fontset': 'dejavuserif', 
          'axes.titlepad': 12, 
          'axes.labelpad': 12}
plt.rcParams.update(params)

# %% [markdown]
# import logging
# logger = logging.getLogger()
# logger.setLevel(logging.DEBUG)

# %%
# Simulation parameters
s = 1.0    # rest length
rA = 1.5   # maximum interaction distance
dim = 3
seed=67


force_names = ['cubic', 'pw. quad.', 'GLS']

defcolors = plt.rcParams['axes.prop_cycle'].by_key()['color']
colors = {'cubic': defcolors[0], 'pw. quad.': defcolors[5], 'GLS': defcolors[6]}

# Solvers
models_ef = {'pw. quad.': cbmos.CBModel(ff.PiecewisePolynomial(), ef.solve_ivp, dim), 
             'cubic': cbmos.CBModel(ff.Cubic(), ef.solve_ivp, dim),
             'GLS': cbmos.CBModel(ff.Gls(), ef.solve_ivp, dim)}
#models_ef = {'pw. quad.': cbmos.CBModel(ff.PiecewisePolynomial(), ef.solve_ivp, dim), 
#             'cubic': cbmos.CBModel(ff.Cubic(), ef.solve_ivp, dim),
 #            'GLS': cbmos.CBModel(ff.LinearExponential(), ef.solve_ivp, dim)}

# %%
# parameters fitted to relaxation time t=1.0h
params_cubic = {"mu": 5.70, "s": s, "rA": rA}
muR = 9.1
ratio = 0.21
params_poly = {'muA': ratio*muR, 'muR': muR, 'rA': rA, 'rR': 1.0/(1.0-np.sqrt(ratio)/3.0), 'n': 1.0, 'p': 1.0}
mu_gls=1.95
params_gls = {'mu': mu_gls, 'a':-2*np.log(0.002/mu_gls)}
params = {'cubic': params_cubic, 'pw. quad.': params_poly, 'GLS': params_gls}
filename_ending = {'cubic': '_cubic', 'pw. quad.': '_pwq', 'GLS': '_gls'}

# %%
def cubic_prime(r, mu, s, rA):
    return mu*(r-rA)*(3*r-2*s-rA)
    
def pwq_prime(r, muA, rA, muR, rR, s):
    return 2*(muR/rR*(1-r/rR)-muA/rA*(1-r/rA))
    
def gls_prime(r, mu, s):
    return mu/(1+r-s)

# %%
# plot function
def plot_population(cell_list, color='blue'):
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    ax.set_aspect('equal')
    #colors = 10*plt.rcParams['axes.prop_cycle'].by_key()['color']
    n_cells = len(cell_list)
    for i in range(n_cells):
        #ax.add_patch(plt.Circle(cell_list[i].position ,0.5,color=colors[i], alpha=0.6))
        ax.add_patch(plt.Circle(cell_list[i].position ,0.5, color=color, alpha=0.4))
        plt.plot(cell_list[i].position[0], cell_list[i].position[1], '.', color=color)
    plt.show()

# %%
def plot_population_3d(cell_list):
    fig = plt.figure()
    ax = fig.add_subplot(projection='3d')
    coords = np.array([cell.position for cell in cell_list])
    ax.scatter(coords[:, 0], coords[:,1], coords[:,2], s=1000)

# %% [markdown]
# # Global adaptive time-stepping for a growing monolayer

# %%
rate = 3.0
tf = 80.0  # final time
t_data = [0.0, tf]

# %%
npr.seed(seed)
cell_list = [
        cl.Cell(
            0, [0., 0., 0.],
            proliferating=True, division_time_generator=lambda t: npr.exponential(rate*(t+1.0)) + t)
        ]

# %%
colors = [defcolors[0], defcolors[5], defcolors[6]]

# Combine into single figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey='row', gridspec_kw={'hspace':0.2, 'wspace': 0.15})
#fig2, (ax3, ax4) = plt.subplots(1, 2, figsize=(12, 5), sharex=True, sharey='row', gridspec_kw={'hspace':0.2, 'wspace': 0.15})


force = 'cubic'

try:
    os.remove('step_sizes'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('time_points'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('AFs'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')

ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.01, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True, 'jacobian': models_ef[force].jacobian, 'force_args': params[force]}, seed=seed)
dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')
print(dts[1])

n_cells = [len(clt) for clt in history]
division_time_indices = np.where(np.diff(n_cells) == 1)[0]
division_times = np.array(ts)[division_time_indices]
for xc in division_times:
    ax1.axvline(x=xc, color='black', linestyle="--", alpha=0.125)
    
ax1.semilogy(ts[:-1],  dts,'-*')
ax1.set_title(r'$\bf{(a)}$')
ax1.set(xlabel='Time in hours')
ax1.set(ylabel='$\Delta t_{max}$ in hours')
#ax1.legend()
ax1.text(-40, 0.001, 'Linear Growth', fontsize=22, rotation='vertical')
ax1.text(15, 6, 'Globally adaptive', fontsize=22)

try:
    os.remove('step_sizes'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('time_points'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('AFs'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')

ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.01, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True, 'jacobian': models_ef[force].jacobian, 'force_args': params[force], 'local_adaptivity': True, 'switch':False}, seed=seed)
dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')
print(dts[1])

n_cells = [len(clt) for clt in history]
division_time_indices = np.where(np.diff(n_cells) == 1)[0]
division_times = np.array(ts)[division_time_indices]
for xc in division_times:
    ax2.axvline(x=xc, color='black', linestyle="--", alpha=0.125)
    
ax2.semilogy(ts[:-1],  dts,'-*')
ax2.set(xlabel='Time in hours')
ax2.text(15, 6, 'Locally adaptive', fontsize=22)
ax2.set_title(r'$\bf{(b)}$')

#ax2.set(ylabel='$\Delta t_{max}$ in hours')
plt.savefig('lin_growth.pdf', bbox_inches='tight')
# Out:
# Nothing to delete.
# /home/kubuntu1804/Documents/cbmos/cbmos/solvers/euler_forward.py:214: RuntimeWarning: divide by zero encountered in double_scalars
#   dt_s = 2.0/abs(w)
# 0.011677291133149267
# Nothing to delete.
# /home/kubuntu1804/Documents/cbmos/cbmos/solvers/euler_forward.py:443: RuntimeWarning: divide by zero encountered in double_scalars
#   dt_s = 2.0/abs(w)
# 0.011677291133149267

# %%
plt.plot(ts, [len(clt) for clt in history ])

# %%
plot_population_3d(history[-1])

# %%
n_cells = len(history[-1])
vtk_file = open('data.vtk', 'w')
vtk_file.write("# vtk DataFile Version 3.0\n")
vtk_file.write("particle_state\n")
vtk_file.write("ASCII\n")
vtk_file.write("DATASET POLYDATA\n")
vtk_file.write("POINTS %d float\n" % n_cells)
n_cells = len(history[-1])
for i in range(n_cells):
    vtk_file.write("%f " %history[-1][i].position[0])
    vtk_file.write("%f " %history[-1][i].position[1])
    vtk_file.write("%f\n" %history[-1][i].position[2])

vtk_file.close()

# %%
import matplotlib
matplotlib.__version__
# Out:
# '3.3.4'

# %%
rate = 1.25
tf = 50.0  # final time
t_data = [0.0, tf]

npr.seed(seed)
cell_list = [
        cl.Cell(
            0, [0., 0.],
            proliferating=True, division_time_generator=lambda t: npr.exponential(rate*(t+1.0)) + t)
        ]

# %%
colors = [defcolors[0], defcolors[5], defcolors[6]]

# Combine into single figure
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5), sharey='row', gridspec_kw={'hspace':0.2, 'wspace': 0.15})
#fig2, (ax3, ax4) = plt.subplots(1, 2, figsize=(12, 5), sharex=True, sharey='row', gridspec_kw={'hspace':0.2, 'wspace': 0.15})


force = 'cubic'

try:
    os.remove('step_sizes'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('time_points'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('AFs'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')

ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.01, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True, 'jacobian': models_ef[force].jacobian, 'force_args': params[force]}, seed=seed)
dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')

n_cells = [len(clt) for clt in history]
division_time_indices = np.where(np.diff(n_cells) == 1)[0]
division_times = np.array(ts)[division_time_indices]
for xc in division_times:
    ax1.axvline(x=xc, color='black', linestyle="--", alpha=0.125)
    
ax1.semilogy(ts[:-1],  dts,'-*')
ax1.set(xlabel='Time in hours')
ax1.set(ylabel='$\Delta t_{max}$ in hours')
#ax1.legend()

try:
    os.remove('step_sizes'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('time_points'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')
try:
    os.remove('AFs'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')

ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.01, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True, 'jacobian': models_ef[force].jacobian, 'force_args': params[force], 'local_adaptivity': True, 'switch':False}, seed=seed)
dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')

n_cells = [len(clt) for clt in history]
division_time_indices = np.where(np.diff(n_cells) == 1)[0]
division_times = np.array(ts)[division_time_indices]
for xc in division_times:
    ax2.axvline(x=xc, color='black', linestyle="--", alpha=0.125)
    
ax2.semilogy(ts[:-1],  dts,'-*')
ax2.set(xlabel='Time in hours')
#ax2.set(ylabel='$\Delta t_{max}$ in hours')
# Out:
# Nothing to delete.
# /home/kubuntu1804/Documents/cbmos/cbmos/solvers/euler_forward.py:214: RuntimeWarning: divide by zero encountered in double_scalars
#   dt_s = 2.0/abs(w)
# Nothing to delete.
# /home/kubuntu1804/Documents/cbmos/cbmos/solvers/euler_forward.py:443: RuntimeWarning: divide by zero encountered in double_scalars
#   dt_s = 2.0/abs(w)
# [Text(0.5, 0, 'Time in hours')]

# %%
# %%time 
ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.01, "eta":0.0001, 'jacobian': models_ef[force].jacobian, 'force_args': params[force]}, seed=seed)
# Out:
# /home/kubuntu1804/Documents/cbmos/cbmos/solvers/euler_forward.py:214: RuntimeWarning: divide by zero encountered in double_scalars
#   dt_s = 2.0/abs(w)
# CPU times: user 1.17 s, sys: 82.1 ms, total: 1.25 s
# Wall time: 2.72 s

# %%
cProfile.run('models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.01, "eta":0.0001, "jacobian": models_ef[force].jacobian, "force_args": params[force]}, seed=seed)', sort=1)
# Out:
#          684900 function calls (682279 primitive calls) in 2.285 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      2030    0.617    0.000    1.188    0.001 __init__.py:329(jacobian)
#     14340    0.288    0.000    0.288    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      2030    0.175    0.000    0.515    0.000 __init__.py:306(f)
#        66    0.145    0.002    2.082    0.032 euler_forward.py:162(_do_global_adaptive_timestepping_with_stability)
# 33204/30778    0.103    0.000    0.482    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#     24558    0.096    0.000    0.096    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#      6090    0.093    0.000    0.141    0.000 force_functions.py:126(__call__)
#    106661    0.092    0.000    0.092    0.000 {built-in method numpy.array}
#      8120    0.068    0.000    0.159    0.000 shape_base.py:512(expand_dims)
#      2030    0.062    0.000    0.128    0.000 __init__.py:208(<listcomp>)
#      2030    0.044    0.000    0.065    0.000 force_functions.py:142(fp)
#     69612    0.042    0.000    0.067    0.000 cell.py:46(__init__)
#     12180    0.033    0.000    0.069    0.000 numeric.py:1308(normalize_axis_tuple)
#         1    0.032    0.032    2.285    2.285 __init__.py:39(simulate)
#     12180    0.027    0.000    0.033    0.000 numeric.py:1358(<listcomp>)
#      2030    0.019    0.000    0.039    0.000 linalg.py:2363(norm)
#      2030    0.019    0.000    0.071    0.000 fromnumeric.py:2105(sum)
#      4060    0.016    0.000    0.037    0.000 twodim_base.py:214(diag)
#      2030    0.011    0.000    0.018    0.000 twodim_base.py:152(eye)
#      2030    0.011    0.000    0.037    0.000 numeric.py:1371(moveaxis)
#      2227    0.011    0.000    0.026    0.000 {method 'format' of 'str' objects}
#      4190    0.011    0.000    0.028    0.000 _ufunc_config.py:32(seterr)
#      4060    0.011    0.000    0.011    0.000 {built-in method numpy.zeros}
#      4190    0.010    0.000    0.069    0.000 fromnumeric.py:70(_wrapreduction)
#      8120    0.010    0.000    0.233    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      4190    0.010    0.000    0.010    0.000 _ufunc_config.py:132(geterr)
#      8120    0.009    0.000    0.011    0.000 shape_base.py:600(<listcomp>)
#      8120    0.008    0.000    0.068    0.000 <__array_function__ internals>:2(where)
#      8120    0.008    0.000    0.187    0.000 <__array_function__ internals>:2(expand_dims)
#      2030    0.008    0.000    0.020    0.000 copy.py:132(deepcopy)
#     49370    0.007    0.000    0.007    0.000 {built-in method builtins.len}
#      8120    0.007    0.000    0.007    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#      2030    0.006    0.000    0.029    0.000 numeric.py:2084(identity)
#        66    0.006    0.000    0.006    0.000 __init__.py:137(<listcomp>)
#      2228    0.006    0.000    0.012    0.000 __init__.py:1904(debug)
#     12180    0.006    0.000    0.006    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#     20432    0.006    0.000    0.016    0.000 _asarray.py:86(asanyarray)
#      4060    0.005    0.000    0.047    0.000 <__array_function__ internals>:2(diag)
#      2030    0.005    0.000    0.005    0.000 {built-in method numpy.empty}
#      2030    0.005    0.000    0.006    0.000 copy.py:252(_keep_alive)
#     14473    0.005    0.000    0.005    0.000 {built-in method builtins.isinstance}
#      8120    0.005    0.000    0.223    0.000 _methods.py:45(_sum)
#      4190    0.005    0.000    0.005    0.000 {built-in method numpy.seterrobj}
#     10215    0.004    0.000    0.008    0.000 _asarray.py:14(asarray)
#      2030    0.004    0.000    0.006    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#      2030    0.004    0.000    0.019    0.000 numeric.py:144(ones)
#      2030    0.004    0.000    0.004    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#      2030    0.004    0.000    0.004    0.000 {built-in method builtins.sorted}
#      2095    0.003    0.000    0.016    0.000 _ufunc_config.py:438(__exit__)
#      2030    0.003    0.000    0.003    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#      2095    0.003    0.000    0.020    0.000 fromnumeric.py:2714(amin)
#      2030    0.003    0.000    0.003    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#        65    0.003    0.000    0.008    0.000 arrayprint.py:863(fillFormat)
#      2030    0.003    0.000    0.009    0.000 fromnumeric.py:1502(diagonal)
#      2095    0.003    0.000    0.018    0.000 _ufunc_config.py:433(__enter__)
#      4190    0.003    0.000    0.003    0.000 fromnumeric.py:71(<dictcomp>)
#      2030    0.003    0.000    0.017    0.000 {method 'max' of 'numpy.ndarray' objects}
#      8380    0.003    0.000    0.003    0.000 {built-in method numpy.geterrobj}
#       132    0.003    0.000    0.011    0.000 shape_base.py:24(atleast_1d)
#      2031    0.003    0.000    0.131    0.000 __init__.py:196(_save_data)
#      2030    0.002    0.000    0.076    0.000 <__array_function__ internals>:2(sum)
#     18270    0.002    0.000    0.002    0.000 {built-in method builtins.next}
#     18534    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#      2228    0.002    0.000    0.004    0.000 __init__.py:1544(isEnabledFor)
#      2030    0.002    0.000    0.043    0.000 <__array_function__ internals>:2(norm)
#      2030    0.002    0.000    0.042    0.000 <__array_function__ internals>:2(moveaxis)
#      2095    0.002    0.000    0.025    0.000 <__array_function__ internals>:2(amin)
#      2030    0.002    0.000    0.012    0.000 <__array_function__ internals>:2(diagonal)
#      2030    0.002    0.000    0.010    0.000 <__array_function__ internals>:2(copyto)
#      2228    0.002    0.000    0.006    0.000 __init__.py:1286(debug)
#      8120    0.002    0.000    0.002    0.000 multiarray.py:311(where)
#        66    0.002    0.000    0.003    0.000 shape_base.py:82(atleast_2d)
#      2095    0.002    0.000    0.002    0.000 _ufunc_config.py:429(__init__)
#      8120    0.002    0.000    0.002    0.000 {built-in method builtins.iter}
#      8120    0.002    0.000    0.002    0.000 shape_base.py:508(_expand_dims_dispatcher)
#        66    0.002    0.000    0.004    0.000 __init__.py:283(_update_positions)
#        65    0.002    0.000    0.002    0.000 __init__.py:220(_get_division_direction)
#      2228    0.001    0.000    0.001    0.000 __init__.py:1530(getEffectiveLevel)
#      6155    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#      4060    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      4258    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#        65    0.001    0.000    0.022    0.000 __init__.py:242(_apply_division)
#      4320    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#      4060    0.001    0.000    0.001    0.000 {built-in method builtins.abs}
#      2030    0.001    0.000    0.001    0.000 numeric.py:1434(<listcomp>)
#    260/65    0.001    0.000    0.003    0.000 arrayprint.py:718(recurser)
#      2030    0.001    0.000    0.014    0.000 _methods.py:37(_amax)
#       384    0.001    0.000    0.001    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#      2030    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#      2030    0.001    0.000    0.001    0.000 force_functions.py:141(derive)
#       130    0.001    0.000    0.001    0.000 {method 'exponential' of 'numpy.random.mtrand.RandomState' objects}
#      4255    0.001    0.000    0.001    0.000 {method 'items' of 'dict' objects}
#       195    0.001    0.000    0.001    0.000 arrayprint.py:947(__call__)
#      4060    0.001    0.000    0.001    0.000 twodim_base.py:210(_diag_dispatcher)
#      4060    0.001    0.000    0.001    0.000 {built-in method _operator.index}
#        65    0.001    0.000    0.001    0.000 arrayprint.py:358(_get_formatdict)
#        65    0.001    0.000    0.013    0.000 arrayprint.py:478(_array2string)
#        66    0.001    0.000    2.083    0.032 __init__.py:274(_calculate_positions)
#      2030    0.001    0.000    0.001    0.000 {built-in method builtins.getattr}
#        66    0.001    0.000    2.082    0.032 euler_forward.py:17(solve_ivp)
#      2030    0.001    0.000    0.001    0.000 fromnumeric.py:2100(_sum_dispatcher)
#       132    0.001    0.000    0.014    0.000 shape_base.py:286(hstack)
#        65    0.001    0.000    0.015    0.000 arrayprint.py:516(array2string)
#        65    0.001    0.000    0.009    0.000 arrayprint.py:409(_get_format_function)
#        66    0.001    0.000    0.001    0.000 __init__.py:138(<listcomp>)
#       130    0.000    0.000    0.000    0.000 {method 'rand' of 'numpy.random.mtrand.RandomState' objects}
#      2095    0.000    0.000    0.000    0.000 fromnumeric.py:2709(_amin_dispatcher)
#      2030    0.000    0.000    0.000    0.000 linalg.py:2359(_norm_dispatcher)
#      2030    0.000    0.000    0.000    0.000 numeric.py:1367(_moveaxis_dispatcher)
#        65    0.000    0.000    0.014    0.000 arrayprint.py:461(wrapper)
#      2030    0.000    0.000    0.000    0.000 fromnumeric.py:1498(_diagonal_dispatcher)
#        65    0.000    0.000    0.001    0.000 arrayprint.py:60(_make_options_dict)
#      2030    0.000    0.000    0.000    0.000 multiarray.py:1043(copyto)
#        66    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#       256    0.000    0.000    0.001    0.000 arrayprint.py:913(<genexpr>)
#        65    0.000    0.000    0.008    0.000 arrayprint.py:836(__init__)
#        65    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#       130    0.000    0.000    0.000    0.000 _eventqueue.py:24(push)
#        66    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       198    0.000    0.000    0.000    0.000 optimize.py:120(__getattr__)
#       195    0.000    0.000    0.000    0.000 arrayprint.py:695(_extendLine)
#       256    0.000    0.000    0.001    0.000 arrayprint.py:918(<genexpr>)
#        65    0.000    0.000    0.015    0.000 arrayprint.py:1473(_array_str_implementation)
#        66    0.000    0.000    0.000    0.000 _eventqueue.py:35(pop)
#       197    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       198    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(concatenate)
#       130    0.000    0.000    0.001    0.000 <ipython-input-8-6e041d9a8e69>:5(<lambda>)
#        65    0.000    0.000    0.001    0.000 fromnumeric.py:2589(amax)
#        66    0.000    0.000    0.005    0.000 shape_base.py:223(vstack)
#       132    0.000    0.000    0.017    0.000 <__array_function__ internals>:2(hstack)
#        65    0.000    0.000    0.008    0.000 arrayprint.py:366(<lambda>)
#       132    0.000    0.000    0.013    0.000 <__array_function__ internals>:2(atleast_1d)
#        65    0.000    0.000    0.003    0.000 arrayprint.py:709(_formatArray)
#        65    0.000    0.000    0.001    0.000 <__array_function__ internals>:2(amax)
#        66    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#       195    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#       198    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#       198    0.000    0.000    0.000    0.000 shape_base.py:219(_vhstack_dispatcher)
#       130    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#        66    0.000    0.000    0.003    0.000 <__array_function__ internals>:2(atleast_2d)
#       200    0.000    0.000    0.000    0.000 {built-in method time.time}
#        65    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#       131    0.000    0.000    0.000    0.000 _eventqueue.py:51(_round_time)
#         1    0.000    0.000    2.285    2.285 {built-in method builtins.exec}
#        66    0.000    0.000    0.005    0.000 <__array_function__ internals>:2(vstack)
#        65    0.000    0.000    0.000    0.000 arrayprint.py:65(<dictcomp>)
#       256    0.000    0.000    0.000    0.000 arrayprint.py:922(<genexpr>)
#        65    0.000    0.000    0.000    0.000 {method 'rstrip' of 'str' objects}
#       256    0.000    0.000    0.000    0.000 arrayprint.py:923(<genexpr>)
#        65    0.000    0.000    0.000    0.000 {method 'discard' of 'set' objects}
#       198    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#        66    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        66    0.000    0.000    0.000    0.000 __init__.py:293(_ode_system)
#        65    0.000    0.000    0.000    0.000 arrayprint.py:827(_none_or_positive_arg)
#        65    0.000    0.000    0.000    0.000 {built-in method _thread.get_ident}
#        65    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#        65    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.dragon4_scientific}
#        65    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_amax_dispatcher)
#       132    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:888(<genexpr>)
#         1    0.000    0.000    2.285    2.285 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'seed' of 'numpy.random.mtrand.RandomState' objects}
#        66    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 __init__.py:214(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _eventqueue.py:13(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:106(<listcomp>)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:891(<genexpr>)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:892(<genexpr>)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:896(<genexpr>)
#         3    0.000    0.000    0.000    0.000 {method 'partition' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 __init__.py:112(<lambda>)
#         1    0.000    0.000    0.000    0.000 __init__.py:119(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _eventqueue.py:18(<listcomp>)
#         4    0.000    0.000    0.000    0.000 arrayprint.py:893(<genexpr>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         4    0.000    0.000    0.000    0.000 arrayprint.py:903(<genexpr>)

# %%
# %%time 
ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.01, "eta":0.0001, 'jacobian': models_ef[force].jacobian, 'force_args': params[force], 'local_adaptivity': True}, seed=seed)
# Out:
# /home/kubuntu1804/Documents/cbmos/cbmos/solvers/euler_forward.py:443: RuntimeWarning: divide by zero encountered in double_scalars
#   dt_s = 2.0/abs(w)
# CPU times: user 2.17 s, sys: 2.91 ms, total: 2.17 s
# Wall time: 2.86 s

# %%
import cProfile

# %%
cProfile.run('models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.001, "eta":0.0001, "jacobian": models_ef[force].jacobian, "force_args": params[force], "local_adaptivity": True}, seed=seed)', sort=1)
# Out:
#          3822659 function calls (3665162 primitive calls) in 5.909 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     22631    0.601    0.000    0.601    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      6159    0.570    0.000    1.658    0.000 __init__.py:306(f)
#    250050    0.535    0.000    0.535    0.000 {built-in method numpy.core._multiarray_umath.dragon4_positional}
#      1455    0.534    0.000    1.011    0.001 __init__.py:329(jacobian)
#    154986    0.441    0.000    0.794    0.000 arrayprint.py:947(__call__)
# 156506/1520    0.344    0.000    1.382    0.001 arrayprint.py:718(recurser)
# 55787/53276    0.193    0.000    0.747    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#    154986    0.183    0.000    0.228    0.000 arrayprint.py:695(_extendLine)
#      9069    0.176    0.000    0.276    0.000 force_functions.py:126(__call__)
#    113796    0.138    0.000    0.138    0.000 {built-in method numpy.array}
#      1520    0.126    0.000    0.891    0.001 arrayprint.py:863(fillFormat)
#     59922    0.119    0.000    0.119    0.000 {built-in method numpy.core._multiarray_umath.dragon4_scientific}
#      1455    0.103    0.000    1.231    0.001 euler_forward.py:394(_choose_dts)
#     44902    0.101    0.000    0.101    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#   1203274    0.098    0.000    0.098    0.000 {built-in method builtins.len}
#    126306    0.081    0.000    0.335    0.000 arrayprint.py:913(<genexpr>)
#     15228    0.076    0.000    0.203    0.000 shape_base.py:512(expand_dims)
#        66    0.065    0.001    5.719    0.087 euler_forward.py:257(_do_local_adaptive_timestepping)
#    126306    0.062    0.000    0.440    0.000 arrayprint.py:918(<genexpr>)
#       560    0.061    0.000    0.893    0.002 euler_forward.py:512(_do_three_levels)
#     18138    0.057    0.000    0.084    0.000 numeric.py:1308(normalize_axis_tuple)
#      5041    0.055    0.000    2.474    0.000 {method 'format' of 'str' objects}
#      7614    0.055    0.000    0.104    0.000 twodim_base.py:214(diag)
#    154986    0.052    0.000    0.052    0.000 {method 'split' of 'str' objects}
#      1455    0.052    0.000    0.121    0.000 __init__.py:208(<listcomp>)
#     51664    0.046    0.000    0.071    0.000 cell.py:46(__init__)
#      4800    0.042    0.000    0.129    0.000 {built-in method builtins.max}
#      1455    0.037    0.000    0.054    0.000 force_functions.py:142(fp)
#      5948    0.031    0.000    0.031    0.000 {built-in method numpy.seterrobj}
#      1520    0.031    0.000    2.373    0.002 arrayprint.py:478(_array2string)
#      1520    0.030    0.000    0.933    0.001 arrayprint.py:836(__init__)
#      7614    0.029    0.000    0.029    0.000 {built-in method numpy.zeros}
#     15228    0.029    0.000    0.257    0.000 <__array_function__ internals>:2(expand_dims)
#      6159    0.028    0.000    0.028    0.000 {built-in method numpy.empty}
#     15228    0.028    0.000    0.561    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      7403    0.027    0.000    0.125    0.000 fromnumeric.py:70(_wrapreduction)
#      5948    0.025    0.000    0.073    0.000 _ufunc_config.py:32(seterr)
#       416    0.024    0.000    0.425    0.001 euler_forward.py:497(_do_two_levels)
#    126306    0.021    0.000    0.030    0.000 arrayprint.py:922(<genexpr>)
#    126306    0.019    0.000    0.033    0.000 arrayprint.py:923(<genexpr>)
#     30200    0.018    0.000    0.086    0.000 arrayprint.py:891(<genexpr>)
#     15228    0.018    0.000    0.533    0.000 _methods.py:45(_sum)
#      6159    0.017    0.000    0.072    0.000 numeric.py:144(ones)
#     10524    0.015    0.000    0.116    0.000 <__array_function__ internals>:2(where)
#     15228    0.014    0.000    0.018    0.000 shape_base.py:600(<listcomp>)
#      5948    0.014    0.000    0.014    0.000 _ufunc_config.py:132(geterr)
#     38677    0.014    0.000    0.045    0.000 _asarray.py:86(asanyarray)
#     30200    0.013    0.000    0.060    0.000 arrayprint.py:888(<genexpr>)
#      1520    0.013    0.000    2.389    0.002 arrayprint.py:461(wrapper)
#      5042    0.013    0.000    0.029    0.000 __init__.py:1904(debug)
#      1520    0.012    0.000    0.012    0.000 arrayprint.py:827(_none_or_positive_arg)
#      1455    0.012    0.000    0.016    0.000 twodim_base.py:152(eye)
#      1455    0.012    0.000    0.012    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     18138    0.011    0.000    0.020    0.000 numeric.py:1358(<listcomp>)
#      7403    0.011    0.000    0.011    0.000 fromnumeric.py:71(<dictcomp>)
#      1455    0.011    0.000    0.011    0.000 {method '__deepcopy__' of 'numpy.ndarray' objects}
#      1520    0.010    0.000    0.956    0.001 arrayprint.py:409(_get_format_function)
#     30200    0.010    0.000    0.011    0.000 arrayprint.py:893(<genexpr>)
#      1520    0.009    0.000    2.414    0.002 arrayprint.py:516(array2string)
#      1455    0.009    0.000    0.030    0.000 numeric.py:1371(moveaxis)
#     30200    0.009    0.000    0.018    0.000 arrayprint.py:892(<genexpr>)
#     18138    0.009    0.000    0.009    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#      1455    0.009    0.000    0.030    0.000 numeric.py:2084(identity)
#      2974    0.009    0.000    0.049    0.000 _ufunc_config.py:438(__exit__)
#         1    0.008    0.008    5.909    5.909 __init__.py:39(simulate)
#       396    0.008    0.000    0.041    0.000 shape_base.py:24(atleast_1d)
#     23096    0.008    0.000    0.008    0.000 {built-in method builtins.isinstance}
#     29961    0.008    0.000    0.008    0.000 {method 'partition' of 'str' objects}
#      2910    0.008    0.000    0.008    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#      1455    0.008    0.000    0.026    0.000 copy.py:132(deepcopy)
#      2910    0.008    0.000    0.083    0.000 fromnumeric.py:2105(sum)
#     16748    0.008    0.000    0.027    0.000 _asarray.py:14(asarray)
#     13434    0.007    0.000    0.007    0.000 {built-in method builtins.abs}
#     10524    0.007    0.000    0.007    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#      5042    0.007    0.000    0.015    0.000 __init__.py:1286(debug)
#      7614    0.007    0.000    0.118    0.000 <__array_function__ internals>:2(diag)
#      1520    0.006    0.000    0.013    0.000 arrayprint.py:60(_make_options_dict)
#      6159    0.006    0.000    0.026    0.000 <__array_function__ internals>:2(copyto)
#     28748    0.006    0.000    0.006    0.000 {method 'rstrip' of 'str' objects}
#      1520    0.006    0.000    0.006    0.000 arrayprint.py:358(_get_formatdict)
#       479    0.005    0.000    0.005    0.000 euler_forward.py:489(_do_single_level)
#      1520    0.005    0.000    0.938    0.001 arrayprint.py:366(<lambda>)
#      1520    0.005    0.000    2.419    0.002 arrayprint.py:1473(_array_str_implementation)
#      5042    0.005    0.000    0.008    0.000 __init__.py:1544(isEnabledFor)
#      1520    0.005    0.000    0.005    0.000 {built-in method builtins.locals}
#      2910    0.005    0.000    0.092    0.000 <__array_function__ internals>:2(sum)
#     30200    0.005    0.000    0.006    0.000 arrayprint.py:903(<genexpr>)
#     30200    0.005    0.000    0.006    0.000 arrayprint.py:896(<genexpr>)
#      1455    0.005    0.000    0.005    0.000 fromnumeric.py:995(_argsort_dispatcher)
#      4365    0.004    0.000    0.026    0.000 fromnumeric.py:52(_wrapfunc)
#        66    0.004    0.000    0.004    0.000 __init__.py:137(<listcomp>)
#      1455    0.004    0.000    0.005    0.000 copy.py:252(_keep_alive)
#      2974    0.004    0.000    0.037    0.000 fromnumeric.py:2714(amin)
#     31911    0.004    0.000    0.004    0.000 {built-in method builtins.next}
#     31670    0.004    0.000    0.004    0.000 {method 'append' of 'list' objects}
#      2974    0.004    0.000    0.037    0.000 _ufunc_config.py:433(__enter__)
#     11896    0.004    0.000    0.004    0.000 {built-in method numpy.geterrobj}
#      1455    0.004    0.000    0.005    0.000 <frozen importlib._bootstrap>:997(_handle_fromlist)
#      1520    0.004    0.000    1.385    0.001 arrayprint.py:709(_formatArray)
#     15228    0.003    0.000    0.003    0.000 shape_base.py:508(_expand_dims_dispatcher)
#      2910    0.003    0.000    0.035    0.000 <__array_function__ internals>:2(searchsorted)
#      1455    0.003    0.000    0.003    0.000 {method 'diagonal' of 'numpy.ndarray' objects}
#      1519    0.003    0.000    0.020    0.000 fromnumeric.py:2589(amax)
#     10524    0.003    0.000    0.003    0.000 multiarray.py:311(where)
#      2974    0.003    0.000    0.044    0.000 <__array_function__ internals>:2(amin)
#      1455    0.003    0.000    0.003    0.000 {built-in method builtins.sorted}
#     15228    0.003    0.000    0.003    0.000 {built-in method builtins.iter}
#      5042    0.003    0.000    0.003    0.000 __init__.py:1530(getEffectiveLevel)
#      2910    0.003    0.000    0.014    0.000 fromnumeric.py:1276(searchsorted)
#      1455    0.003    0.000    0.007    0.000 fromnumeric.py:1502(diagonal)
#       132    0.003    0.000    0.004    0.000 shape_base.py:82(atleast_2d)
#      1519    0.002    0.000    0.025    0.000 <__array_function__ internals>:2(amax)
#      1455    0.002    0.000    0.017    0.000 fromnumeric.py:999(argsort)
#      1455    0.002    0.000    0.035    0.000 <__array_function__ internals>:2(moveaxis)
#      2974    0.002    0.000    0.002    0.000 _ufunc_config.py:429(__init__)
#      1455    0.002    0.000    0.025    0.000 <__array_function__ internals>:2(argsort)
#      1455    0.002    0.000    0.011    0.000 <__array_function__ internals>:2(diagonal)
#      1456    0.002    0.000    0.124    0.000 __init__.py:196(_save_data)
#      5820    0.002    0.000    0.002    0.000 {built-in method builtins.getattr}
#      7535    0.002    0.000    0.002    0.000 {built-in method builtins.issubclass}
#        65    0.002    0.000    0.002    0.000 __init__.py:220(_get_division_direction)
#        66    0.002    0.000    0.009    0.000 __init__.py:283(_update_positions)
#      8923    0.002    0.000    0.002    0.000 {method 'items' of 'dict' objects}
#      7614    0.002    0.000    0.002    0.000 twodim_base.py:210(_diag_dispatcher)
#      1520    0.002    0.000    0.002    0.000 {method 'copy' of 'dict' objects}
#        65    0.001    0.000    0.037    0.001 __init__.py:242(_apply_division)
#      2910    0.001    0.000    0.001    0.000 {method 'get' of 'dict' objects}
#      3438    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#      1455    0.001    0.000    0.001    0.000 {method 'swapaxes' of 'numpy.ndarray' objects}
#      1520    0.001    0.000    0.001    0.000 arrayprint.py:65(<dictcomp>)
#      1520    0.001    0.000    0.001    0.000 {built-in method _thread.get_ident}
#       396    0.001    0.000    0.050    0.000 shape_base.py:286(hstack)
#      5885    0.001    0.000    0.001    0.000 {built-in method builtins.id}
#      1455    0.001    0.000    0.001    0.000 {method 'insert' of 'list' objects}
#      6159    0.001    0.000    0.001    0.000 multiarray.py:1043(copyto)
#       130    0.001    0.000    0.001    0.000 {method 'exponential' of 'numpy.random.mtrand.RandomState' objects}
#      1520    0.001    0.000    0.001    0.000 {method 'discard' of 'set' objects}
#      1455    0.001    0.000    0.001    0.000 numeric.py:1434(<listcomp>)
#      1455    0.001    0.000    0.001    0.000 force_functions.py:141(derive)
#      2910    0.001    0.000    0.001    0.000 fromnumeric.py:2100(_sum_dispatcher)
#      2910    0.001    0.000    0.001    0.000 {built-in method _operator.index}
#        66    0.001    0.000    5.721    0.087 __init__.py:274(_calculate_positions)
#      1520    0.001    0.000    0.001    0.000 {method 'update' of 'dict' objects}
#      2910    0.001    0.000    0.001    0.000 fromnumeric.py:1272(_searchsorted_dispatcher)
#      2974    0.001    0.000    0.001    0.000 fromnumeric.py:2709(_amin_dispatcher)
#        66    0.001    0.000    5.720    0.087 euler_forward.py:17(solve_ivp)
#       528    0.001    0.000    0.005    0.000 <__array_function__ internals>:2(concatenate)
#       130    0.001    0.000    0.001    0.000 {method 'rand' of 'numpy.random.mtrand.RandomState' objects}
#       396    0.000    0.000    0.057    0.000 <__array_function__ internals>:2(hstack)
#       396    0.000    0.000    0.045    0.000 <__array_function__ internals>:2(atleast_1d)
#      1520    0.000    0.000    0.000    0.000 {method 'add' of 'set' objects}
#        66    0.000    0.000    0.000    0.000 __init__.py:138(<listcomp>)
#      1519    0.000    0.000    0.000    0.000 fromnumeric.py:2584(_amax_dispatcher)
#        66    0.000    0.000    0.000    0.000 {method 'tolist' of 'numpy.ndarray' objects}
#      1455    0.000    0.000    0.000    0.000 fromnumeric.py:1498(_diagonal_dispatcher)
#      1455    0.000    0.000    0.000    0.000 numeric.py:1367(_moveaxis_dispatcher)
#       132    0.000    0.000    0.006    0.000 shape_base.py:223(vstack)
#       130    0.000    0.000    0.001    0.000 _eventqueue.py:24(push)
#       528    0.000    0.000    0.001    0.000 shape_base.py:219(_vhstack_dispatcher)
#        66    0.000    0.000    0.000    0.000 _eventqueue.py:35(pop)
#       198    0.000    0.000    0.000    0.000 optimize.py:120(__getattr__)
#        66    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#       528    0.000    0.000    0.000    0.000 shape_base.py:208(_arrays_for_stack_dispatcher)
#       130    0.000    0.000    0.001    0.000 <ipython-input-8-6e041d9a8e69>:5(<lambda>)
#       132    0.000    0.000    0.004    0.000 <__array_function__ internals>:2(atleast_2d)
#       132    0.000    0.000    0.011    0.000 <__array_function__ internals>:2(vstack)
#        66    0.000    0.000    0.000    0.000 {built-in method _heapq.heappop}
#       200    0.000    0.000    0.000    0.000 {built-in method time.time}
#       130    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#       528    0.000    0.000    0.000    0.000 multiarray.py:143(concatenate)
#         1    0.000    0.000    5.909    5.909 {built-in method builtins.exec}
#       131    0.000    0.000    0.000    0.000 _eventqueue.py:51(_round_time)
#       396    0.000    0.000    0.000    0.000 shape_base.py:20(_atleast_1d_dispatcher)
#        66    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#        66    0.000    0.000    0.000    0.000 __init__.py:293(_ode_system)
#       132    0.000    0.000    0.000    0.000 shape_base.py:78(_atleast_2d_dispatcher)
#         1    0.000    0.000    5.909    5.909 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {method 'seed' of 'numpy.random.mtrand.RandomState' objects}
#         1    0.000    0.000    0.000    0.000 _eventqueue.py:13(__init__)
#         1    0.000    0.000    0.000    0.000 __init__.py:106(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _eventqueue.py:18(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heapify}
#         1    0.000    0.000    0.000    0.000 __init__.py:112(<lambda>)
#         1    0.000    0.000    0.000    0.000 __init__.py:214(<listcomp>)
#         1    0.000    0.000    0.000    0.000 __init__.py:119(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# %%time 
ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {'dt': 0.003}, seed=seed)
# Out:
# CPU times: user 7.48 s, sys: 136 ms, total: 7.62 s
# Wall time: 8.08 s

# %%
# %%time 
ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.001, "eta":0.0001}, seed=seed)
# Out:
# CPU times: user 1.77 s, sys: 12.3 ms, total: 1.79 s
# Wall time: 2.14 s

# %%
0.01/4
# Out:
# 0.0025

# %%
try:
    os.remove('step_sizes'+filename_ending[force]+'.txt')
except FileNotFoundError:
    print('Nothing to delete.')

# %%
ts, history = models_ef[force].simulate(cell_list, t_data, params[force], {"eps": 0.001, "eta":0.0001, "out": filename_ending[force], 'write_to_file': True, 'jacobian': models_ef[force].jacobian, 'force_args': params[force]}, seed=seed)

# %%
dts = np.loadtxt('step_sizes'+filename_ending[force]+'.txt')

# %%
dts[:,0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-91339309ce7c> in <module>
# ----> 1 dts[:,0]
#
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
